# %%
import pandas as pd

# %%
train = pd.read_parquet("../data/processed/train.parquet")

# %%
import numpy as np

edge_list = np.load("../data/graph/edge_list.npy")

edge_list.shape
# Out:
# (25600164, 2)

# %%
num_info = np.load("../data/graph/num_info.npy")

num_info.shape
# Out:
# (2,)
